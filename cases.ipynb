# %% [markdown]
# # First we import our libraries for scrapping Missouri courts

# %%
from courts.mo.search_cases import do_search_cases
from courts.mo.search_cases import pd_search_cases
from pandas import DataFrame

# %% [markdown]
# # We then make a search for all traffic cases since April 3rd in Court code "CT16"

# %%
pd_search_cases(courtCode="CT16", startDate="04/02/2024")
# Out:
#     confidentialFlag caseNumber caseTypeCode  initFiling cortCode  \
# 0                  N  220291890           O5  04/02/2024       16
# 1                  N  220291903           O5  04/02/2024       16
# 2                  N  220291874           O5  04/02/2024       16
# 3                  N  220291876           O5  04/02/2024       16
# 4                  N  220291901           O5  04/02/2024       16
# ..               ...        ...          ...         ...      ...
# 625                N  220291878           O5  04/02/2024       16
# 626                N  220213080           O5  04/02/2024       16
# 627                N  240257643           O5  04/02/2024       16
# 628                N  240257642           O6  04/02/2024       16
# 629                N  230449221           O5  04/02/2024       16
#
#                                        caseStyle locnCode  \
# 0    CITY OF LONE JACK V KORTNEY MACHELLE PULLEY       L9
# ...
