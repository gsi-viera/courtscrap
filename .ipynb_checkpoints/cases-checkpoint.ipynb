# %%
from courts.mo.search_cases import search_cases
from pandas import DataFrame

# %%
cases = search_cases()

# %%
DataFrame(cases)
# Out:
#    confidentialFlag    caseNumber caseTypeCode  initFiling cortCode  \
# 0                 N  24AU-TR00002           T2  03/25/2024       12
# 1                 N     230794011           O5  03/27/2024       12
# 2                 N     230794025           O5  03/27/2024       12
# 3                 N     230794015           O5  03/27/2024       12
# 4                 N     230794006           O5  03/27/2024       12
# 5                 N     230794003           O5  03/27/2024       12
# 6                 N     230794029           O5  03/27/2024       12
# 7                 N     230794021           O5  03/27/2024       12
# 8                 N     230794001           O5  03/27/2024       12
# 9                 N     230794027           O5  03/27/2024       12
# 10                N  24AU-TR00002           T2  03/25/2024       12
# 11                N     230794011           O5  03/27/2024       12
# 12                N     230794025           O5  03/27/2024       12
# ...
